# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(1.0,100.0)

S = np.zeros_like(x)
err = np.zeros_like(x)

def afunc(k):
    return ((-1)**(k+1))*(1/((2*k)-1))

S[0] = 4*afunc(1)

err[0] = abs(S[0] - np.pi)

for i in range(1,len(x)):
    S[i] = S[i-1] + (4*afunc(x[i]))
    err[i] = abs(S[i]-np.pi)
    
fig, (ax1, ax2) = plt.subplots(2,
                               figsize=(5,10))

ax1.plot(x,S)
ax1.set_ylim([3.0,3.7])
ax1.set_xlabel('Number of terms')
ax2.set_ylabel('Approximation')
ax1.grid('on')

ax2.plot(x,err)
ax2.set_ylim([0,1])
ax2.set_xlabel('Number of terms')
ax2.set_ylabel('Error')
ax2.grid('on')
plt.show()

# %%
pi_10 = round(np.pi,8)
print(pi_10)

x=np.arange(1.0,10000.0)

S = np.zeros_like(x)
err = np.zeros_like(x)

def afunc(k):
    return ((-1)**(k+1))*(1/((2*k)-1))

S[0] = 4*afunc(1)

err[0] = abs(S[0] - np.pi)

for i in range(1,len(x)):
    S[i] = S[i-1] + (4*afunc(x[i]))
    err[i] = abs(S[i]-np.pi)

for i in range(0,len(err)):
    S[i]=round(S[i],8)
    
print(S[98000])

p=0
while S[p] != pi_10:
    p+=1
    if p == len(err):
        break
    
print(p)
# Out:
# 3.14159265
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[135], line 23
#      20 for i in range(0,len(err)):
#      21     S[i]=round(S[i],8)
# ---> 23 print(S[98000])
#      25 p=0
#      26 while S[p] != pi_10:
#
# IndexError: index 98000 is out of bounds for axis 0 with size 9999
